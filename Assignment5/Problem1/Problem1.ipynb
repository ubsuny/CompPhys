# %% [markdown]
# ## Problem 1
# *25 points*
#
# This problem involves scattering trajectories and cross sections using the calculus tools covered in class. Please do your work in `Problem1/Problem1.ipynb`.

# %% [markdown]
# ### Problem 1a
# *15 points*
#
# Using the tools covered in class (specifically those used in CompPhys/Calculus/scattering.ipynb), study classical scattering from a hard sphere and from the Lennard–Jones potential. The C++ files and SWIG files have been copied to this folder for you.
#
# Specifically, for both the hard-sphere and Lennard–Jones potentials, do the following:
#
# 1. Plot the potential and some typical trajectories. Choose a few values of energy ($E$), and make a separate plot for each value; for each plot, choose a range of impact parameters ($b$) to plot.
# 2. Compute and plot the differential scattering cross section versus $\theta_s$. Recall that the differential cross section is given by:
#
# $$
# \frac{d\sigma}{d\Omega} = \frac{b}{\sin\theta_s}\left\vert \frac{d\theta_s}{db}\right|^{-1}
# $$
#
# To compute $\frac{d\theta_s}{db}$, you will need to determine the scattering angle for different impact parameters, and then take the derivative numerically (using, for example, the five-point stencil method).

# %%
! swig -c++ -python swig/scattering.i
! python swig/setup.py build_ext --inplace

# %%
import os
import sys
sys.path.append( os.path.abspath("swig") )
import scattering
import numpy as np
import matplotlib.pyplot as plt

# Make fonts bigger by default
plt.rcParams.update({
    'legend.fontsize': 'large',
    'axes.labelsize': 'large',
    'axes.titlesize':'large',
    'xtick.labelsize':'large',
    'ytick.labelsize':'large'
})

# %% [markdown]
# ### Hard sphere potential

# %%
# Plot the potential V(r) versus r in this cell

# %%
# Plot some representative trajectories here. Choose a few values of energy (E), 
# and make a separate plot for each value; for each plot, choose a range of impact 
# parameters () to plot.

# %%
# Compute and plot the differential scattering cross section versus theta_s here

# %% [markdown]
# ### Lennard–Jones potential

# %%
# Plot the potential V(r) versus r in this cell

# %%
# Plot some representative trajectories here. Choose a few values of energy (E), 
# and make a separate plot for each value; for each plot, choose a range of impact 
# parameters () to plot.

# %%
# Compute and plot the differential scattering cross section versus theta_s here

# %% [markdown]
# ### Problem 1b
# *10 points*
#
# For the Lennard–Jones potential, compute the trajectories for some values of the energy that
# demonstrate the phenomenon of orbiting. What is the maximum number of orbits that you can
# generate by carefully tuning the energy and impact parameter?
#
# Refer back to the lecture notes for guidance on the orbiting phenomenon (recall that we used the effective potential with a centrifugal term).

# %%
# Do Problem 1b here
