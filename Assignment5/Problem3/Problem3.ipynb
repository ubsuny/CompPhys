# %% [markdown]
# # Problem 3
# *25 point*
#
# Write a program to solve for the currents in a resistor cube. There are 12 resistors, one along each
# edge. A voltage source is connected across a body diagonal of the cube.
#
# ![cube.jpg](attachment:7c82cdb2-5812-4498-9281-eb2262d939f2.jpg)

# %% [markdown]
# ## Problem 3a
# *10 points*
#
# Using your program (i.e., using the linear algebra techniques covered in class, not just solving the
# problem directly!), find the equivalent resistance for the symmetric case when all the resistors
# have the same resistance, R= 1 Ω. You might remember this problem from your E&M class.
#
# Refer to CompPhys/LinearAlgebra/wheatstone.ipynb for guidance. You might find it useful to draw the circuit in 2D (which you can do for a cube), instead of 3D.

# %%
# Do Problem 3a here

# %% [markdown]
# ## Problem 3b
# *15 points*
#
# Vary the resistance of one resistor at a time. How many unique cases are there? Plot the equiva-
# lent resistance as a function of the resistance of the one resistor being varied for all of the unique
# cases.

# %%
# Do Problem 3b here
