# %%
import cairosvg
import io
from PIL import Image

def svg2numpy(filename):
    """Load an SVG file and return image in Numpy array"""
    # Make memory buffer
    mem = io.BytesIO()
    # Convert SVG to PNG in memory
    cairosvg.svg2png(url=filename, write_to=mem)
    # Convert PNG to Numpy array
    return np.array(Image.open(mem))

# %%
# %pip install cairosvg
# Out:
# Collecting cairosvg
#   Downloading cairosvg-2.8.2-py3-none-any.whl.metadata (2.7 kB)
# Collecting cairocffi (from cairosvg)
#   Downloading cairocffi-1.7.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting cssselect2 (from cairosvg)
#   Downloading cssselect2-0.8.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: defusedxml in /opt/venv/lib/python3.12/site-packages (from cairosvg) (0.7.1)
# Requirement already satisfied: pillow in /opt/venv/lib/python3.12/site-packages (from cairosvg) (11.3.0)
# Requirement already satisfied: tinycss2 in /opt/venv/lib/python3.12/site-packages (from cairosvg) (1.4.0)
# Requirement already satisfied: cffi>=1.1.0 in /opt/venv/lib/python3.12/site-packages (from cairocffi->cairosvg) (2.0.0)
# Requirement already satisfied: webencodings in /opt/venv/lib/python3.12/site-packages (from cssselect2->cairosvg) (0.5.1)
# Requirement already satisfied: pycparser in /opt/venv/lib/python3.12/site-packages (from cffi>=1.1.0->cairocffi->cairosvg) (2.23)
# Downloading cairosvg-2.8.2-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 kB 1.4 MB/s eta 0:00:00
# Downloading cairocffi-1.7.1-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 5.9 MB/s eta 0:00:00
# Downloading cssselect2-0.8.0-py3-none-any.whl (15 kB)
# Installing collected packages: cssselect2, cairocffi, cairosvg
# Successfully installed cairocffi-1.7.1 cairosvg-2.8.2 cssselect2-0.8.0
# Note: you may need to restart the kernel to use updated packages.
